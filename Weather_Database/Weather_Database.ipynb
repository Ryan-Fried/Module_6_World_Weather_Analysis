# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm count
len(cities)
# Out:
# 768

# %%
# Import the requests library
import requests
# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our cities list
for i, city in enumerate(cities):
    # Group cities into sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city
    city_url = url + '&q=' + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | koumra
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | leningradskaya
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | faanui
# Processing Record 10 of Set 1 | takoradi
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | erzurum
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | aksarka
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | rawson
# Processing Record 20 of Set 1 | port moresby
# Processing Record 21 of Set 1 | sur
# Processing Record 22 of Set 1 | kurya
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | safaqis
# City not found. Skipping...
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | bridlington
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | shingu
# Processing Record 34 of Set 1 | katsuyama
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | bengkulu
# Processing Record 38 of Set 1 | sungaipenuh
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | nantucket
# Processing Record 41 of Set 1 | bagdarin
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | millinocket
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | mount isa
# Processing Record 46 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 47 of Set 1 | okato
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | paramonga
# Processing Record 50 of Set 1 | burnie
# Processing Record 1 of Set 2 | papara
# Processing Record 2 of Set 2 | nabire
# Processing Record 3 of Set 2 | thinadhoo
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | oktyabrskoye
# Processing Record 6 of Set 2 | guerrero negro
# Processing Record 7 of Set 2 | vestmannaeyjar
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | krasnoselkup
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | anadyr
# Processing Record 12 of Set 2 | wajir
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | alugan
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | pitkyaranta
# Processing Record 19 of Set 2 | alofi
# Processing Record 20 of Set 2 | eyl
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | broken hill
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | half moon bay
# Processing Record 25 of Set 2 | alim
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | padang
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | haines junction
# Processing Record 33 of Set 2 | xining
# Processing Record 34 of Set 2 | narrabri
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | odweyne
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | cap malheureux
# Processing Record 40 of Set 2 | palkonda
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | moosomin
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | shimoda
# Processing Record 49 of Set 2 | kosa
# Processing Record 50 of Set 2 | nongpoh
# Processing Record 1 of Set 3 | katha
# City not found. Skipping...
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | quang ngai
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | jiangkou
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | cairns
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 12 of Set 3 | juneau
# Processing Record 13 of Set 3 | kawardha
# Processing Record 14 of Set 3 | pocone
# Processing Record 15 of Set 3 | ha tinh
# Processing Record 16 of Set 3 | price
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | sola
# Processing Record 19 of Set 3 | huntington
# Processing Record 20 of Set 3 | catamarca
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | mme
# City not found. Skipping...
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | waverly
# Processing Record 26 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 3 | port blair
# Processing Record 28 of Set 3 | sol-iletsk
# Processing Record 29 of Set 3 | imbituba
# Processing Record 30 of Set 3 | punta arenas
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | uribia
# Processing Record 34 of Set 3 | ozernovskiy
# Processing Record 35 of Set 3 | huarmey
# Processing Record 36 of Set 3 | nalut
# Processing Record 37 of Set 3 | wasilla
# Processing Record 38 of Set 3 | makung
# City not found. Skipping...
# Processing Record 39 of Set 3 | sarana
# Processing Record 40 of Set 3 | aswan
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | port lincoln
# Processing Record 43 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 3 | constitucion
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 3 | kushmurun
# Processing Record 48 of Set 3 | arandis
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | hofn
# Processing Record 1 of Set 4 | jurbarkas
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | lisiy nos
# Processing Record 5 of Set 4 | viedma
# Processing Record 6 of Set 4 | clyde river
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | raymond
# Processing Record 9 of Set 4 | la ronge
# Processing Record 10 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | pitimbu
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | san quintin
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | vicente guerrero
# Processing Record 17 of Set 4 | ati
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | fresnillo
# Processing Record 20 of Set 4 | barcelos
# Processing Record 21 of Set 4 | manggar
# Processing Record 22 of Set 4 | corinto
# Processing Record 23 of Set 4 | mokrousovo
# Processing Record 24 of Set 4 | aykino
# Processing Record 25 of Set 4 | west wendover
# Processing Record 26 of Set 4 | bocaranga
# City not found. Skipping...
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | kalga
# Processing Record 31 of Set 4 | coquimbo
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | rio hato
# Processing Record 34 of Set 4 | mareeba
# Processing Record 35 of Set 4 | bonavista
# Processing Record 36 of Set 4 | hokitika
# Processing Record 37 of Set 4 | parras
# City not found. Skipping...
# Processing Record 38 of Set 4 | nador
# Processing Record 39 of Set 4 | lexington
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | jalu
# Processing Record 42 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 4 | nagato
# Processing Record 44 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 4 | makakilo city
# Processing Record 46 of Set 4 | westport
# Processing Record 47 of Set 4 | west richland
# Processing Record 48 of Set 4 | kapaa
# Processing Record 49 of Set 4 | wanaka
# Processing Record 50 of Set 4 | moshenskoye
# Processing Record 1 of Set 5 | gan yavne
# Processing Record 2 of Set 5 | bathsheba
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | naze
# Processing Record 5 of Set 5 | kahului
# Processing Record 6 of Set 5 | tukrah
# Processing Record 7 of Set 5 | korla
# Processing Record 8 of Set 5 | fort saint james
# Processing Record 9 of Set 5 | niteroi
# Processing Record 10 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 5 | san andres
# Processing Record 12 of Set 5 | ruteng
# Processing Record 13 of Set 5 | bhadasar
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | mayo
# Processing Record 16 of Set 5 | leh
# Processing Record 17 of Set 5 | kavaratti
# Processing Record 18 of Set 5 | wewak
# Processing Record 19 of Set 5 | idrinskoye
# Processing Record 20 of Set 5 | fortuna
# Processing Record 21 of Set 5 | kaka
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | yinchuan
# Processing Record 24 of Set 5 | koumac
# Processing Record 25 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 5 | itarema
# Processing Record 27 of Set 5 | leningradskiy
# Processing Record 28 of Set 5 | hervey bay
# Processing Record 29 of Set 5 | sioux lookout
# Processing Record 30 of Set 5 | mangrol
# Processing Record 31 of Set 5 | bandarbeyla
# Processing Record 32 of Set 5 | sirnak
# Processing Record 33 of Set 5 | stromness
# Processing Record 34 of Set 5 | ust-tsilma
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | buenos aires
# Processing Record 37 of Set 5 | berestechko
# Processing Record 38 of Set 5 | soma
# Processing Record 39 of Set 5 | northam
# Processing Record 40 of Set 5 | ust-kalmanka
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | pangai
# Processing Record 43 of Set 5 | dicabisagan
# Processing Record 44 of Set 5 | sangar
# Processing Record 45 of Set 5 | waingapu
# Processing Record 46 of Set 5 | grindavik
# Processing Record 47 of Set 5 | bellevue
# Processing Record 48 of Set 5 | dauriya
# Processing Record 49 of Set 5 | hami
# Processing Record 50 of Set 5 | avarua
# Processing Record 1 of Set 6 | peto
# Processing Record 2 of Set 6 | pisco
# Processing Record 3 of Set 6 | guasdualito
# Processing Record 4 of Set 6 | chopda
# Processing Record 5 of Set 6 | ponta delgada
# Processing Record 6 of Set 6 | mar del plata
# Processing Record 7 of Set 6 | faya
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | abbeville
# Processing Record 10 of Set 6 | igarka
# Processing Record 11 of Set 6 | sibu
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | kamenka
# Processing Record 14 of Set 6 | xai-xai
# Processing Record 15 of Set 6 | bat khela
# Processing Record 16 of Set 6 | aktau
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | chimore
# Processing Record 20 of Set 6 | khani
# Processing Record 21 of Set 6 | vizinga
# Processing Record 22 of Set 6 | kedougou
# Processing Record 23 of Set 6 | urengoy
# Processing Record 24 of Set 6 | zhetybay
# City not found. Skipping...
# Processing Record 25 of Set 6 | totskoye
# Processing Record 26 of Set 6 | nuuk
# Processing Record 27 of Set 6 | salalah
# Processing Record 28 of Set 6 | ternate
# Processing Record 29 of Set 6 | krasnyy chikoy
# Processing Record 30 of Set 6 | upernavik
# Processing Record 31 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 6 | walvis bay
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | akyab
# Processing Record 35 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 36 of Set 6 | nara
# Processing Record 37 of Set 6 | iskateley
# Processing Record 38 of Set 6 | tucuman
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | namibe
# Processing Record 41 of Set 6 | mabaruma
# Processing Record 42 of Set 6 | trofors
# Processing Record 43 of Set 6 | buchanan
# Processing Record 44 of Set 6 | mujiayingzi
# Processing Record 45 of Set 6 | labuhan
# Processing Record 46 of Set 6 | chokurdakh
# Processing Record 47 of Set 6 | greenfield
# Processing Record 48 of Set 6 | lavrentiya
# Processing Record 49 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 6 | georgetown
# Processing Record 1 of Set 7 | hualmay
# Processing Record 2 of Set 7 | camocim
# Processing Record 3 of Set 7 | zhovti vody
# Processing Record 4 of Set 7 | candelaria
# Processing Record 5 of Set 7 | sao felix do xingu
# Processing Record 6 of Set 7 | hovd
# Processing Record 7 of Set 7 | necochea
# Processing Record 8 of Set 7 | saint-paul
# Processing Record 9 of Set 7 | santa clara
# Processing Record 10 of Set 7 | saiha
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | taoudenni
# Processing Record 13 of Set 7 | lagos
# Processing Record 14 of Set 7 | maragogi
# Processing Record 15 of Set 7 | amqui
# Processing Record 16 of Set 7 | worthington
# Processing Record 17 of Set 7 | road town
# Processing Record 18 of Set 7 | sembe
# Processing Record 19 of Set 7 | dingle
# Processing Record 20 of Set 7 | tuatapere
# Processing Record 21 of Set 7 | palaikastron
# Processing Record 22 of Set 7 | nainpur
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | kulotino
# Processing Record 25 of Set 7 | chany
# Processing Record 26 of Set 7 | dudinka
# Processing Record 27 of Set 7 | atar
# Processing Record 28 of Set 7 | burns lake
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | ust-kuyga
# Processing Record 31 of Set 7 | surt
# Processing Record 32 of Set 7 | marshfield
# Processing Record 33 of Set 7 | xinpu
# Processing Record 34 of Set 7 | xuchang
# Processing Record 35 of Set 7 | beloha
# Processing Record 36 of Set 7 | vestmanna
# Processing Record 37 of Set 7 | martapura
# Processing Record 38 of Set 7 | taltal
# Processing Record 39 of Set 7 | hvide sande
# Processing Record 40 of Set 7 | glebychevo
# Processing Record 41 of Set 7 | uberlandia
# Processing Record 42 of Set 7 | pori
# Processing Record 43 of Set 7 | belmonte
# Processing Record 44 of Set 7 | mwene-ditu
# Processing Record 45 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 7 | port augusta
# Processing Record 48 of Set 7 | kushiro
# Processing Record 49 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 7 | port elizabeth
# Processing Record 1 of Set 8 | fairbanks
# Processing Record 2 of Set 8 | omsukchan
# Processing Record 3 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | douglas
# Processing Record 6 of Set 8 | cabadiangan
# Processing Record 7 of Set 8 | pyapon
# Processing Record 8 of Set 8 | cayenne
# Processing Record 9 of Set 8 | hasaki
# Processing Record 10 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 8 | zahesi
# Processing Record 12 of Set 8 | kodiak
# Processing Record 13 of Set 8 | sosua
# Processing Record 14 of Set 8 | lixourion
# Processing Record 15 of Set 8 | masvingo
# Processing Record 16 of Set 8 | villa maria
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | cuenca
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | camacha
# Processing Record 21 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 8 | neuquen
# Processing Record 23 of Set 8 | le pradet
# Processing Record 24 of Set 8 | dunedin
# Processing Record 25 of Set 8 | hambantota
# Processing Record 26 of Set 8 | portland
# Processing Record 27 of Set 8 | quatre cocos
# Processing Record 28 of Set 8 | truth or consequences
# Processing Record 29 of Set 8 | leirvik
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | miura
# Processing Record 32 of Set 8 | cherskiy
# Processing Record 33 of Set 8 | tanshui
# City not found. Skipping...
# Processing Record 34 of Set 8 | brest
# Processing Record 35 of Set 8 | lakes entrance
# Processing Record 36 of Set 8 | port hardy
# Processing Record 37 of Set 8 | todos santos
# Processing Record 38 of Set 8 | kon tum
# Processing Record 39 of Set 8 | gushikawa
# Processing Record 40 of Set 8 | iracoubo
# Processing Record 41 of Set 8 | masuda
# Processing Record 42 of Set 8 | vila
# Processing Record 43 of Set 8 | ulmi
# Processing Record 44 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 8 | xam nua
# Processing Record 47 of Set 8 | muroto
# Processing Record 48 of Set 8 | rosarito
# Processing Record 49 of Set 8 | ozinki
# Processing Record 50 of Set 8 | maniitsoq
# Processing Record 1 of Set 9 | inhambane
# Processing Record 2 of Set 9 | klaksvik
# Processing Record 3 of Set 9 | sakakah
# Processing Record 4 of Set 9 | emerald
# Processing Record 5 of Set 9 | meulaboh
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | severo-kurilsk
# Processing Record 8 of Set 9 | nanakuli
# Processing Record 9 of Set 9 | oxapampa
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | la romana
# Processing Record 12 of Set 9 | kalino
# Processing Record 13 of Set 9 | simplicio mendes
# Processing Record 14 of Set 9 | tornio
# Processing Record 15 of Set 9 | sobolevo
# Processing Record 16 of Set 9 | udachnyy
# Processing Record 17 of Set 9 | matagami
# Processing Record 18 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 9 | aras
# Processing Record 20 of Set 9 | san antonio
# Processing Record 21 of Set 9 | solenzo
# Processing Record 22 of Set 9 | aracuai
# Processing Record 23 of Set 9 | ust-nera
# Processing Record 24 of Set 9 | bumba
# Processing Record 25 of Set 9 | tenenkou
# Processing Record 26 of Set 9 | saint marys
# Processing Record 27 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 9 | coahuayana
# Processing Record 29 of Set 9 | swan hill
# Processing Record 30 of Set 9 | tura
# Processing Record 31 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 9 | miri
# Processing Record 33 of Set 9 | adrar
# Processing Record 34 of Set 9 | macaubas
# Processing Record 35 of Set 9 | conde
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | chicama
# Processing Record 38 of Set 9 | zyryanka
# Processing Record 39 of Set 9 | olafsvik
# Processing Record 40 of Set 9 | kutum
# Processing Record 41 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 9 | sunrise manor
# Processing Record 43 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 9 | irondequoit
# Processing Record 45 of Set 9 | toamasina
# Processing Record 46 of Set 9 | karwar
# Processing Record 47 of Set 9 | nanortalik
# Processing Record 48 of Set 9 | airai
# Processing Record 49 of Set 9 | vila franca do campo
# Processing Record 50 of Set 9 | khorixas
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | flinders
# Processing Record 3 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 10 | chuy
# Processing Record 5 of Set 10 | rocha
# Processing Record 6 of Set 10 | strezhevoy
# Processing Record 7 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 8 of Set 10 | pemangkat
# Processing Record 9 of Set 10 | omboue
# Processing Record 10 of Set 10 | tazovskiy
# Processing Record 11 of Set 10 | boysun
# Processing Record 12 of Set 10 | evensk
# Processing Record 13 of Set 10 | ordzhonikidze
# Processing Record 14 of Set 10 | solnechnyy
# Processing Record 15 of Set 10 | conceicao do araguaia
# Processing Record 16 of Set 10 | port macquarie
# Processing Record 17 of Set 10 | vanavara
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | yakeshi
# Processing Record 20 of Set 10 | sayyan
# Processing Record 21 of Set 10 | ponerihouen
# Processing Record 22 of Set 10 | horsham
# Processing Record 23 of Set 10 | andra
# Processing Record 24 of Set 10 | fengkou
# Processing Record 25 of Set 10 | pareora
# Processing Record 26 of Set 10 | muzhi
# Processing Record 27 of Set 10 | nishihara
# Processing Record 28 of Set 10 | dale
# Processing Record 29 of Set 10 | richards bay
# Processing Record 30 of Set 10 | zhangye
# Processing Record 31 of Set 10 | palmer
# Processing Record 32 of Set 10 | labrea
# Processing Record 33 of Set 10 | san pedro
# Processing Record 34 of Set 10 | la ferte-bernard
# Processing Record 35 of Set 10 | katsuura
# Processing Record 36 of Set 10 | ales
# Processing Record 37 of Set 10 | ramotswa
# Processing Record 38 of Set 10 | cadillac
# Processing Record 39 of Set 10 | kidal
# Processing Record 40 of Set 10 | wajima
# Processing Record 41 of Set 10 | lasa
# Processing Record 42 of Set 10 | port hedland
# Processing Record 43 of Set 10 | kununurra
# Processing Record 44 of Set 10 | chiredzi
# Processing Record 45 of Set 10 | porto empedocle
# Processing Record 46 of Set 10 | lima
# Processing Record 47 of Set 10 | beyneu
# Processing Record 48 of Set 10 | voznesenye
# Processing Record 49 of Set 10 | sawtell
# Processing Record 50 of Set 10 | altagracia de orituco
# Processing Record 1 of Set 11 | gazimurskiy zavod
# Processing Record 2 of Set 11 | agva
# City not found. Skipping...
# Processing Record 3 of Set 11 | sept-iles
# Processing Record 4 of Set 11 | stornoway
# Processing Record 5 of Set 11 | careiro da varzea
# Processing Record 6 of Set 11 | nizwa
# Processing Record 7 of Set 11 | monroe
# Processing Record 8 of Set 11 | imuris
# Processing Record 9 of Set 11 | saurimo
# Processing Record 10 of Set 11 | harnosand
# Processing Record 11 of Set 11 | huanren
# Processing Record 12 of Set 11 | chake chake
# Processing Record 13 of Set 11 | panama city
# Processing Record 14 of Set 11 | santa rosalia
# Processing Record 15 of Set 11 | pakokku
# Processing Record 16 of Set 11 | glotovka
# Processing Record 17 of Set 11 | lukulu
# Processing Record 18 of Set 11 | sao desiderio
# Processing Record 19 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 11 | avera
# Processing Record 21 of Set 11 | heilbron
# Processing Record 22 of Set 11 | mende
# Processing Record 23 of Set 11 | lazaro cardenas
# Processing Record 24 of Set 11 | teahupoo
# Processing Record 25 of Set 11 | tsabong
# Processing Record 26 of Set 11 | iralaya
# Processing Record 27 of Set 11 | baykit
# Processing Record 28 of Set 11 | sisimiut
# Processing Record 29 of Set 11 | baturaja
# Processing Record 30 of Set 11 | uarini
# Processing Record 31 of Set 11 | santa cruz
# Processing Record 32 of Set 11 | kuching
# Processing Record 33 of Set 11 | narasannapeta
# Processing Record 34 of Set 11 | kismayo
# Processing Record 35 of Set 11 | san ramon de la nueva oran
# Processing Record 36 of Set 11 | marienburg
# Processing Record 37 of Set 11 | sorland
# Processing Record 38 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 39 of Set 11 | manokwari
# Processing Record 40 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 11 | reefton
# City not found. Skipping...
# Processing Record 42 of Set 11 | saint-fabien
# City not found. Skipping...
# Processing Record 43 of Set 11 | jacareacanga
# Processing Record 44 of Set 11 | beaverlodge
# Processing Record 45 of Set 11 | bosaso
# Processing Record 46 of Set 11 | mastic beach
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | kita
# Processing Record 49 of Set 11 | kirakira
# Processing Record 50 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 12 | peniche
# Processing Record 2 of Set 12 | parfenyevo
# Processing Record 3 of Set 12 | cabedelo
# Processing Record 4 of Set 12 | praia da vitoria
# Processing Record 5 of Set 12 | cururupu
# Processing Record 6 of Set 12 | buala
# Processing Record 7 of Set 12 | boa vista
# Processing Record 8 of Set 12 | teya
# Processing Record 9 of Set 12 | rassvet
# Processing Record 10 of Set 12 | somotillo
# Processing Record 11 of Set 12 | ballarat
# Processing Record 12 of Set 12 | kenai
# Processing Record 13 of Set 12 | bud
# Processing Record 14 of Set 12 | prado
# Processing Record 15 of Set 12 | saldanha
# Processing Record 16 of Set 12 | nepalganj
# City not found. Skipping...
# Processing Record 17 of Set 12 | ugoofaaru
# Processing Record 18 of Set 12 | awjilah
# Processing Record 19 of Set 12 | satara
# Processing Record 20 of Set 12 | rakhya
# City not found. Skipping...
# Processing Record 21 of Set 12 | kazuno
# Processing Record 22 of Set 12 | kabinda
# Processing Record 23 of Set 12 | algodones
# Processing Record 24 of Set 12 | tommot
# Processing Record 25 of Set 12 | marsa matruh
# Processing Record 26 of Set 12 | pekan
# Processing Record 27 of Set 12 | galle
# Processing Record 28 of Set 12 | pechory
# Processing Record 29 of Set 12 | am timan
# Processing Record 30 of Set 12 | pedreiras
# Processing Record 31 of Set 12 | setermoen
# Processing Record 32 of Set 12 | honiara
# Processing Record 33 of Set 12 | yazman
# Processing Record 34 of Set 12 | mandalgovi
# Processing Record 35 of Set 12 | cartagena
# Processing Record 36 of Set 12 | vitoria
# Processing Record 37 of Set 12 | noyabrsk
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | bayir
# Processing Record 40 of Set 12 | manaure
# Processing Record 41 of Set 12 | san policarpo
# Processing Record 42 of Set 12 | jizan
# Processing Record 43 of Set 12 | bakchar
# Processing Record 44 of Set 12 | joacaba
# Processing Record 45 of Set 12 | sulurpeta
# City not found. Skipping...
# Processing Record 46 of Set 12 | alibag
# Processing Record 47 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 48 of Set 12 | bambanglipuro
# Processing Record 49 of Set 12 | lobau
# Processing Record 50 of Set 12 | sompeta
# Processing Record 1 of Set 13 | zhigansk
# Processing Record 2 of Set 13 | rio grande
# Processing Record 3 of Set 13 | comodoro rivadavia
# Processing Record 4 of Set 13 | moose factory
# Processing Record 5 of Set 13 | saquarema
# Processing Record 6 of Set 13 | harper
# Processing Record 7 of Set 13 | qasigiannguit
# Processing Record 8 of Set 13 | amapa
# Processing Record 9 of Set 13 | kampene
# Processing Record 10 of Set 13 | ndele
# Processing Record 11 of Set 13 | sokolo
# Processing Record 12 of Set 13 | fujieda
# Processing Record 13 of Set 13 | mufulira
# Processing Record 14 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 13 | luang prabang
# Processing Record 16 of Set 13 | mogwase
# Processing Record 17 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 13 | marawi
# Processing Record 19 of Set 13 | secunda
# Processing Record 20 of Set 13 | maralal
# Processing Record 21 of Set 13 | liverpool
# Processing Record 22 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 13 | sao domingos
# Processing Record 24 of Set 13 | srednekolymsk
# Processing Record 25 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 13 | arlit
# Processing Record 27 of Set 13 | koslan
# Processing Record 28 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 13 | sibolga
# Processing Record 30 of Set 13 | ixtapa
# Processing Record 31 of Set 13 | shirvan
# Processing Record 32 of Set 13 | sagae
# Processing Record 33 of Set 13 | belaya gora
# Processing Record 34 of Set 13 | kiama
# Processing Record 35 of Set 13 | verkhnevilyuysk
# Processing Record 36 of Set 13 | asosa
# Processing Record 37 of Set 13 | laguna
# Processing Record 38 of Set 13 | paka
# Processing Record 39 of Set 13 | sorong
# Processing Record 40 of Set 13 | abu samrah
# Processing Record 41 of Set 13 | morehead
# Processing Record 42 of Set 13 | adilabad
# Processing Record 43 of Set 13 | calama
# Processing Record 44 of Set 13 | presidencia roque saenz pena
# Processing Record 45 of Set 13 | noumea
# Processing Record 46 of Set 13 | stanghelle
# Processing Record 47 of Set 13 | sicuani
# Processing Record 48 of Set 13 | williams lake
# Processing Record 49 of Set 13 | masty
# Processing Record 50 of Set 13 | valdivia
# Processing Record 1 of Set 14 | bogande
# Processing Record 2 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 3 of Set 14 | glubokoe
# City not found. Skipping...
# Processing Record 4 of Set 14 | yarkovo
# Processing Record 5 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 6 of Set 14 | abu zabad
# Processing Record 7 of Set 14 | yulara
# Processing Record 8 of Set 14 | mgandu
# Processing Record 9 of Set 14 | sitka
# Processing Record 10 of Set 14 | axim
# Processing Record 11 of Set 14 | nadym
# Processing Record 12 of Set 14 | haimen
# Processing Record 13 of Set 14 | ilebo
# Processing Record 14 of Set 14 | umm lajj
# Processing Record 15 of Set 14 | puerto escondido
# Processing Record 16 of Set 14 | muros
# Processing Record 17 of Set 14 | sarahan
# Processing Record 18 of Set 14 | kattivakkam
# Processing Record 19 of Set 14 | azare
# Processing Record 20 of Set 14 | tessalit
# Processing Record 21 of Set 14 | pathardi
# Processing Record 22 of Set 14 | naron
# Processing Record 23 of Set 14 | mackenzie
# Processing Record 24 of Set 14 | labuan
# Processing Record 25 of Set 14 | vanimo
# Processing Record 26 of Set 14 | apatou
# Processing Record 27 of Set 14 | vao
# Processing Record 28 of Set 14 | mashhad
# Processing Record 29 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 14 | talas
# Processing Record 31 of Set 14 | emba
# Processing Record 32 of Set 14 | sabha
# Processing Record 33 of Set 14 | saint-georges
# Processing Record 34 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 35 of Set 14 | ellisras
# Processing Record 36 of Set 14 | metro
# Processing Record 37 of Set 14 | sar-e pul
# Processing Record 38 of Set 14 | karratha
# Processing Record 39 of Set 14 | sabang
# Processing Record 40 of Set 14 | pryazha
# Processing Record 41 of Set 14 | luanda
# Processing Record 42 of Set 14 | yeppoon
# Processing Record 43 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 14 | tabuk
# Processing Record 45 of Set 14 | praia
# Processing Record 46 of Set 14 | san vicente
# Processing Record 47 of Set 14 | rapar
# Processing Record 48 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 49 of Set 14 | latung
# Processing Record 50 of Set 14 | sao miguel do araguaia
# Processing Record 1 of Set 15 | boldumsaz
# Processing Record 2 of Set 15 | tirumakudal narsipur
# Processing Record 3 of Set 15 | horta
# Processing Record 4 of Set 15 | nioro
# Processing Record 5 of Set 15 | lakatoro
# Processing Record 6 of Set 15 | tadine
# Processing Record 7 of Set 15 | camana
# Processing Record 8 of Set 15 | florianopolis
# Processing Record 9 of Set 15 | bira
# Processing Record 10 of Set 15 | bacolod
# Processing Record 11 of Set 15 | port shepstone
# Processing Record 12 of Set 15 | markova
# Processing Record 13 of Set 15 | bulaevo
# Processing Record 14 of Set 15 | bam
# Processing Record 15 of Set 15 | kerrville
# Processing Record 16 of Set 15 | buluang
# Processing Record 17 of Set 15 | camopi
# Processing Record 18 of Set 15 | usmajac
# Processing Record 19 of Set 15 | bousso
# Processing Record 20 of Set 15 | yumen
# Processing Record 21 of Set 15 | tilichiki
# Processing Record 22 of Set 15 | santa rosa
# Processing Record 23 of Set 15 | maba
# Processing Record 24 of Set 15 | edson
# Processing Record 25 of Set 15 | sarakhs
# Processing Record 26 of Set 15 | maun
# Processing Record 27 of Set 15 | matara
# Processing Record 28 of Set 15 | dafeng
# Processing Record 29 of Set 15 | changtu
# Processing Record 30 of Set 15 | chokwe
# Processing Record 31 of Set 15 | watsa
# Processing Record 32 of Set 15 | jumla
# Processing Record 33 of Set 15 | benxi
# Processing Record 34 of Set 15 | rettikhovka
# Processing Record 35 of Set 15 | yabassi
# Processing Record 36 of Set 15 | namatanai
# Processing Record 37 of Set 15 | oyama
# Processing Record 38 of Set 15 | salinas
# Processing Record 39 of Set 15 | te anau
# Processing Record 40 of Set 15 | tamiahua
# Processing Record 41 of Set 15 | paita
# Processing Record 42 of Set 15 | margate
# Processing Record 43 of Set 15 | cascais
# Processing Record 44 of Set 15 | norsup
# Processing Record 45 of Set 15 | loharu
# Processing Record 46 of Set 15 | batsfjord
# Processing Record 47 of Set 15 | pangnirtung
# Processing Record 48 of Set 15 | aban
# Processing Record 49 of Set 15 | acarau
# Processing Record 50 of Set 15 | tovuz
# Processing Record 1 of Set 16 | red bluff
# Processing Record 2 of Set 16 | saint anthony
# Processing Record 3 of Set 16 | suihua
# Processing Record 4 of Set 16 | aksu
# Processing Record 5 of Set 16 | tandil
# Processing Record 6 of Set 16 | loikaw
# Processing Record 7 of Set 16 | verkh-usugli
# Processing Record 8 of Set 16 | batagay-alyta
# Processing Record 9 of Set 16 | basna
# Processing Record 10 of Set 16 | west bay
# Processing Record 11 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 16 | malakal
# Processing Record 13 of Set 16 | ormond beach
# Processing Record 14 of Set 16 | tacna
# Processing Record 15 of Set 16 | jackson
# Processing Record 16 of Set 16 | natal
# Processing Record 17 of Set 16 | nouadhibou
# Processing Record 18 of Set 16 | khonuu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
# Convert the array of dictionaries to a Pandas DataFrame
weather_database_df = pd.DataFrame(city_data)
weather_database_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Koumra   8.9126   17.5539     87.28        30          69
# 1       Mahebourg -20.4081   57.7000     75.49        83          40
# 2       Hithadhoo  -0.6000   73.0833     82.49        74          56
# 3      Kaitangata -46.2817  169.8464     46.04        94          89
# 4  Leningradskaya  46.3214   39.3877     37.80        58          13
# 5       Ilulissat  69.2167  -51.1000     12.22        67          75
# 6        Luderitz -26.6481   15.1594     66.60        72           2
# 7       Cape Town -33.9258   18.4232     70.09        59           0
# 8          Faanui -16.4833 -151.7500     78.21        73          95
# 9        Takoradi   4.8845   -1.7554     80.78        81          94
#
#    Wind Speed Country Current Description
# 0        4.63      TD       broken clouds
# 1        3.44      MU    scattered clouds
# 2       12.19      MV       broken clouds
# 3        7.18      NZ     overcast clouds
# 4       11.70      RU          few clouds
# 5        2.30      GL       broken clouds
# 6       12.64      NA           clear sky
# 7       11.50      ZA           clear sky
# 8        4.92      PF     overcast clouds
# 9       10.00      GH     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
weather_database_df = weather_database_df[new_column_order]
weather_database_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Koumra      TD   8.9126   17.5539     87.28        30
# 1         Mahebourg      MU -20.4081   57.7000     75.49        83
# 2         Hithadhoo      MV  -0.6000   73.0833     82.49        74
# 3        Kaitangata      NZ -46.2817  169.8464     46.04        94
# 4    Leningradskaya      RU  46.3214   39.3877     37.80        58
# ..              ...     ...      ...       ...       ...       ...
# 691    Ormond Beach      US  29.2858  -81.0559     74.16        49
# 692           Tacna      PE -18.0056  -70.2483     68.20        56
# 693         Jackson      US  42.4165 -122.8345     50.95        93
# 694           Natal      BR  -5.7950  -35.2094     86.65        62
# 695      Nouadhibou      MR  20.9310  -17.0347     68.31        80
#
#      Cloudiness  Wind Speed Current Description
# 0            69        4.63       broken clouds
# 1            40        3.44    scattered clouds
# 2            56       12.19       broken clouds
# 3            89        7.18     overcast clouds
# 4            13       11.70          few clouds
# ..          ...         ...                 ...
# 691           1        9.22           clear sky
# 692           0       10.36           clear sky
# 693          90        4.61     overcast clouds
# 694          40       18.41    scattered clouds
# 695         100       11.79     overcast clouds
#
# [696 rows x 9 columns]

# %%
# Create the output file CSV
output_data_file = "WeatherPy_Database.csv"
# Export the city data into a CSV
weather_database_df.to_csv(output_data_file, index_label='City_ID')
